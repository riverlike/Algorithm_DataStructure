# %% [markdown]
# #큐(Queue)
# - FIFO(First In First Out)구조
#  - 입구와 출구가 따로 있는 원통구조.
#  - 원통 양쪽이 뚫려있어 한쪽에서는 삽입(enQueue), 반대쪽에서는 추출(deQueue)만 진행된다.
#  - 데이터의 흐름 : 선입선출(선착순)
# - 응용사례
#  - 클라이언트 접속 대기열
#  - 운영체제 스케쥴러(프로세스 할당)
#  - 네트워크 패킷 버퍼

# %% [markdown]
# # 큐의 간단 구현
#  - front node: 첫번째데이터(머리) ,  데이터를 추출하는 위치
#  - rear node: 마지막데이터(꼬리), 데이터가 삽입되는 위치
#  - push : 데이터 삽입
#  - pop : 데이터 추출

# %%
# push
queue = [None, None, None, None, None]
front = rear = -1 
print("큐 상태  : front",front, ' rear:', rear, 'data size:', rear-front)
rear += 1
queue[rear] = "화사"
print('enQueue <-- ', queue[rear], 'front',front, ' rear:', rear, 'data size:', rear-front)
rear += 1
queue[rear] = "솔라"
print('enQueue <-- ', queue[rear], 'front',front, ' rear:', rear, 'data size:', rear-front)
rear += 1
queue[rear] = "문별"
print('enQueue <-- ', queue[rear], 'front',front, ' rear:', rear, 'data size:', rear-front)

print("큐 상태  : front",front, ' rear:', rear, 'data size:', rear-front)
print ( '[출구] <-- ', end='')
for i in range(0, len(queue), 1) :
	print(queue[i], end=' ')
print ( '<-- [입구] ')
# Out:
# 큐 상태  : front -1  rear: -1 data size: 0
# enQueue <--  화사 front -1  rear: 0 data size: 1
# enQueue <--  솔라 front -1  rear: 1 data size: 2
# enQueue <--  문별 front -1  rear: 2 data size: 3
# 큐 상태  : front -1  rear: 2 data size: 3
# [출구] <-- 화사 솔라 문별 None None <-- [입구]

# %%
# pop
queue = ["화사", "솔라", "문별", None, None]
front = -1
rear = 2

print("큐 상태  : front",front, ' rear:', rear, 'data size:', rear-front)
print ( '[출구] <-- ', end = ' ')
for i in range(0, len(queue), 1) :
	print(queue[i], end = ' ')
print ( '<-- [입구] ')
print("-------------------")


front += 1
data = queue[front]
queue[front] = None
print('deQueue --> ', data, 'front',front, ' rear:', rear, 'data size:', rear-front)

front += 1
data = queue[front]
queue[front] = None
print('deQueue --> ', data, 'front',front, ' rear:', rear, 'data size:', rear-front)

front += 1
data = queue[front]
queue[front] = None
print('deQueue --> ', data, 'front',front, ' rear:', rear, 'data size:', rear-front)
print("-------------------")

print("큐 상태  : front",front, ' rear:', rear, 'data size:', rear-front)
print ( '[출구] <-- ', end = '')
for i in range(0, len(queue), 1) :
	print(queue[i], end = ' ')
print ( '<-- [입구] ')
# Out:
# 큐 상태  : front -1  rear: 2 data size: 3
# [출구] <--  화사 솔라 문별 None None <-- [입구]
# -------------------
# deQueue -->  화사 front 0  rear: 2 data size: 2
# deQueue -->  솔라 front 1  rear: 2 data size: 1
# deQueue -->  문별 front 2  rear: 2 data size: 0
# -------------------
# 큐 상태  : front 2  rear: 2 data size: 0
# [출구] <-- None None None None None <-- [입구]

# %% [markdown]
# # 큐의 일반 구현

# %%
def isQueueFull() :
	global SIZE, queue, front, rear
	if (rear == SIZE-1) :
		return True
	else :
		return False

SIZE = 5
queue = ["화사", "솔라", "문별", "휘인", "선미"]
front = -1
rear = 4

print("큐가 꽉 찼는지 여부 ==>", isQueueFull())
# Out:
# 큐가 꽉 찼는지 여부 ==> True

# %%
def isQueueFull() :
	global SIZE, queue, front, rear
	if (rear == SIZE-1) :
		return True
	else :
		return False

def enQueue(data) :
	global SIZE, queue, front, rear
	if (isQueueFull()) :
		print("큐가 꽉 찼습니다.")
		return
	rear += 1
	queue[rear] = data

SIZE = 5
queue = ["화사", "솔라", "문별", "휘인", None]
front = -1
rear = 3

print(queue)
enQueue("선미")
print(queue)
enQueue("재남")
# Out:
# ['화사', '솔라', '문별', '휘인', None]
# ['화사', '솔라', '문별', '휘인', '선미']
# 큐가 꽉 찼습니다.

# %%
def isQueueEmpty() :
	global SIZE, queue, front, rear
	if (front == rear) :
		return True
	else :
		return False

SIZE = 5
queue = [ None for _ in range(SIZE) ]
front = rear = -1

print("큐가 비었는지 여부 ==>", isQueueEmpty())
# Out:
# 큐가 비었는지 여부 ==> True

# %%
def isQueueEmpty() :
	global SIZE, queue, front, rear
	if (front == rear) :
		return True
	else :
		return False

def deQueue() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	front += 1
	data = queue[front]
	queue[front] = None
	return data

SIZE = 5
queue = ["화사", None, None, None, None]
front = -1
rear = 0

print(queue)
retData = deQueue()
print("추출한 데이터 -->", retData)
print(queue)
retData = deQueue()
# Out:
# ['화사', None, None, None, None]
# 추출한 데이터 --> 화사
# [None, None, None, None, None]
# 큐가 비었습니다.

# %% [markdown]
# - peek : 다음에 추출될 데이터를 미리 확인

# %%
def isQueueEmpty() :
	global SIZE, queue, front, rear
	if (front == rear) :
		return True
	else :
		return False

def peek() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	return queue[front+1]

SIZE = 5
queue = ["화사", "솔라", "문별", None, None]
front = -1
rear = 2

print(queue)
retData = peek()
print("다음에 추출될 데이터 확인 -->", retData)
print(queue)
# Out:
# ['화사', '솔라', '문별', None, None]
# 다음에 추출될 데이터 확인 --> 화사
# ['화사', '솔라', '문별', None, None]

# %% [markdown]
# ### 큐 전체 코드 ver1
# - 큐사이즈 만큼의 push, pop을 테스트할수 있다.
# - 하지만 push된 자리게 계속 비어있어 계속적으로 큐를 사용할수 없다.
#  - 아래의 다음버전에서 업그레이드 해볼예정.

# %%
## 함수 선언 부분 ##
def isQueueFull() :
	global SIZE, queue, front, rear
	if (rear == SIZE-1) :
		return True
	else :
		return False

def isQueueEmpty() :
	global SIZE, queue, front, rear
	if (front == rear) :
		return True
	else :
		return False

def enQueue(data) :
	global SIZE, queue, front, rear
	if (isQueueFull()) :
		print("큐가 꽉 찼습니다.")
		return
	rear += 1
	queue[rear] = data

def deQueue() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	front += 1
	data = queue[front]
	queue[front] = None
	return data

def peek() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	return queue[front+1]

## 전역 변수 선언 부분 ##
SIZE = int(input("큐의 크기를 입력하세요 ==> "))
queue = [ None for _ in range(SIZE) ]
front = rear = -1

## 메인 코드 부분 ##
if __name__ == "__main__" :
	select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> ")

	while (select != 'X' and select != 'x') :
		if select=='I' or select =='i' :
			data = input("입력할 데이터 ==> ")
			enQueue(data)
			print("큐 상태 : ", queue)
		elif select=='E' or select =='e' :
			data = deQueue()
			print("추출된 데이터 ==> ", data)
			print("큐 상태 : ", queue)
		elif select=='V' or select =='v' :
			data = peek()
			print("확인된 데이터 ==> ", data)
			print("큐 상태 : ", queue)
		else :
			print("입력이 잘못됨")

		select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> ")

	print("프로그램 종료!")
# Out:
# 큐의 크기를 입력하세요 ==> 4
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> banana
# 큐 상태 :  ['banana', None, None, None]
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> apple
# 큐 상태 :  ['banana', 'apple', None, None]
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> cherry
# 큐 상태 :  ['banana', 'apple', 'cherry', None]
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> mango
# 큐 상태 :  ['banana', 'apple', 'cherry', 'mango']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> fineapple
# 큐가 꽉 찼습니다.
# 큐 상태 :  ['banana', 'apple', 'cherry', 'mango']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> E
# 추출된 데이터 ==>  banana
# 큐 상태 :  [None, 'apple', 'cherry', 'mango']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> dkdk
# 큐가 꽉 찼습니다.
# 큐 상태 :  [None, 'apple', 'cherry', 'mango']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> X
# 프로그램 종료!

# %% [markdown]
# - ver1 개선
#  - 큐가 다찬 경우 데이터를 앞쪽으로 이동하는 처리
#  - 큐에 데이터가 pop될때마다 옮기면 오버헤드가 많이 발생하므로 다찼을때 이동시켜줌.

# %%
def isQueueFull() :
	global SIZE, queue, front, rear
	if (rear != SIZE-1) : #큐가 차지 않은경우
		return False
	elif (rear == SIZE -1) and (front == -1) : #마지막까지 차있고 앞쪽도 비워있지 않은 경우 확인
		return True     #큐가 차있음
	else : #큐가 뒤쪽이 차 있지만, 앞쪽이 비워있는 경우
		print('moving data------------------')
        #앞쪽으로 전체 데이터를 한칸씩 옮기는 작업
		for i in range(front+1, SIZE) :
			print(' i:', i, 'front:',front,  'rear:',rear, 'data:', queue[i])            
			queue[i-1] = queue[i] #데이터를 앞쪽으로 옮겨줌.
			queue[i] = None
		front -= 1 
		rear -= 1 
		print('moving data------------------')        
		return False

SIZE = 5
queue = [None, None, "문별", "휘인", "선미"]
front = 1
rear = 4
print("큐 상태 ==> ", queue)
print("큐가 꽉 찼는지 여부 ==>", isQueueFull())
print("큐 상태 ==> ", queue)
print("큐가 꽉 찼는지 여부 ==>", isQueueFull())
print("큐 상태 ==> ", queue)
# Out:
# 큐 상태 ==>  [None, None, '문별', '휘인', '선미']
# moving data------------------
#  i: 2 front: 1 rear: 4 data: 문별
#  i: 3 front: 1 rear: 4 data: 휘인
#  i: 4 front: 1 rear: 4 data: 선미
# moving data------------------
# 큐가 꽉 찼는지 여부 ==> False
# 큐 상태 ==>  [None, '문별', '휘인', '선미', None]
# 큐가 꽉 찼는지 여부 ==> False
# 큐 상태 ==>  [None, '문별', '휘인', '선미', None]

# %% [markdown]
# ### 큐 전체 코드 ver2
#  - 개선

# %%
## 함수 선언 부분 ##
def isQueueFull() :
	global SIZE, queue, front, rear
	if (rear != SIZE-1) :
		return False
	elif (rear == SIZE -1) and (front == -1) :
		return True
	else :
		for i in range(front+1, SIZE) :
			queue[i-1] = queue[i]
			queue[i] = None
		front -= 1
		rear -= 1
		return False

def isQueueEmpty() :
	global SIZE, queue, front, rear
	if (front == rear) :
		return True
	else :
		return False

def enQueue(data) :
	global SIZE, queue, front, rear
	if (isQueueFull()) :
		print("큐가 꽉 찼습니다.")
		return
	rear += 1
	queue[rear] = data

def deQueue() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	front += 1
	data = queue[front]
	queue[front] = None
	return data

def peek() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	return queue[front+1]

## 전역 변수 선언 부분 ##
SIZE = int(input("큐의 크기를 입력하세요 ==> "))
queue = [ None for _ in range(SIZE) ]
front = rear = -1

## 메인 코드 부분 ##
if __name__ == "__main__" :
	select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> ")

	while (select != 'X' and select != 'x') :
		if select=='I' or select =='i' :
			data = input("입력할 데이터 ==> ")
			enQueue(data)
			print("큐 상태 : ", queue)
		elif select=='E' or select =='e' :
			data = deQueue()
			print("추출된 데이터 ==> ", data)
			print("큐 상태 : ", queue)
		elif select=='V' or select =='v' :
			data = peek()
			print("확인된 데이터 ==> ", data)
			print("큐 상태 : ", queue)
		else :
			print("입력이 잘못됨")

		select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> ")

	print("프로그램 종료!")
# Out:
# 큐의 크기를 입력하세요 ==> 4
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> I
# 입력할 데이터 ==> banana
# 큐 상태 :  ['banana', None, None, None]
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> I
# 입력할 데이터 ==> apple
# 큐 상태 :  ['banana', 'apple', None, None]
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> I
# 입력할 데이터 ==> mango
# 큐 상태 :  ['banana', 'apple', 'mango', None]
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> I
# 입력할 데이터 ==> cherry
# 큐 상태 :  ['banana', 'apple', 'mango', 'cherry']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> I
# 입력할 데이터 ==> fineapple
# 큐가 꽉 찼습니다.
# 큐 상태 :  ['banana', 'apple', 'mango', 'cherry']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> E
# 추출된 데이터 ==>  banana
# 큐 상태 :  [None, 'apple', 'mango', 'cherry']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> E
# 추출된 데이터 ==>  apple
# 큐 상태 :  [None, None, 'mango', 'cherry']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> I
# 입력할 데이터 ==> snack
# 큐 상태 :  [None, 'mango', 'cherry', 'snack']
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나 선택 ==> I
# 입력할 데이터 ==> potato
# 큐 상태 :  ['mango', 'cherry', 'snack', 'potato']
# ...

# %% [markdown]
# # 큐의 응용 - 원형큐
#  - 순차 큐(Sequential Queue) : 한줄에 데이터가 차례대로 입출력처리됨
#  - 원형큐(Circular Queue) : 처음과 끝이 연결된구조로 뒤가 꽉차있으나 앞쪽이 비워진경우 데이터 이동없이 앞쪽을 채울수 있는 구조.
#
#   - 코드에 버그있음: front 설정하는 부분 ( 앞쪽이 하나 비워져있는데 큐가 다차있다고 나옴, 수정 필요!)

# %%
## 함수 선언 부분 ##
def isQueueFull() :
	global SIZE, queue, front, rear
	if ( (rear + 1) % SIZE == front) :
		return True
	else :
		return False

def isQueueEmpty() :
	global SIZE, queue, front, rear
	if (front == rear) :
		return True
	else :
		return False

def enQueue(data) :
	global SIZE, queue, front, rear
	if (isQueueFull()) :
		print("큐가 꽉 찼습니다.")
		return
	rear = (rear + 1) % SIZE
	queue[rear] = data

def deQueue() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	front = (front + 1) % SIZE
	data = queue[front]
	queue[front] = None
	return data

def peek() :
	global SIZE, queue, front, rear
	if (isQueueEmpty()) :
		print("큐가 비었습니다.")
		return None
	return queue[(front + 1) % SIZE]

## 전역 변수 선언 부분 ##
SIZE = int(input("큐의 크기를 입력하세요 ==> "))
queue = [ None for _ in range(SIZE) ]
front = rear = 0

## 메인 코드 부분 ##
if __name__ == "__main__" :
	select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> ")

	while (select != 'X' and select != 'x') :
		if select=='I' or select =='i' :
			data = input("입력할 데이터 ==> ")
			enQueue(data)
			print("큐 상태 : ", queue)
			print("front : ", front, ", rear : ", rear)
		elif select=='E' or select =='e' :
			data = deQueue()
			print("추출된 데이터 ==> ", data)
			print("큐 상태 : ", queue)
			print("front : ", front, ", rear : ", rear)
		elif select=='V' or select =='v' :
			data = peek()
			print("확인된 데이터 ==> ", data)
			print("큐 상태 : ", queue)
			print("front : ", front, ", rear : ", rear)
		else :
			print("입력이 잘못됨")

		select = input("삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> ")

	print("프로그램 종료!")
# Out:
# 큐의 크기를 입력하세요 ==> 5
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> apple
# 큐 상태 :  [None, 'apple', None, None, None]
# front :  0 , rear :  1
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> b
# 큐 상태 :  [None, 'apple', 'b', None, None]
# front :  0 , rear :  2
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> c
# 큐 상태 :  [None, 'apple', 'b', 'c', None]
# front :  0 , rear :  3
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> E
# 추출된 데이터 ==>  apple
# 큐 상태 :  [None, None, 'b', 'c', None]
# front :  1 , rear :  3
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> E
# 추출된 데이터 ==>  b
# 큐 상태 :  [None, None, None, 'c', None]
# front :  2 , rear :  3
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> E
# 추출된 데이터 ==>  c
# 큐 상태 :  [None, None, None, None, None]
# front :  3 , rear :  3
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> V
# 큐가 비었습니다.
# 확인된 데이터 ==>  None
# 큐 상태 :  [None, None, None, None, None]
# front :  3 , rear :  3
# 삽입(I)/추출(E)/확인(V)/종료(X) 중 하나를 선택 ==> I
# 입력할 데이터 ==> d
# ...
