# %% [markdown]
# # 선형리스트와 단순연결리스트
# - 선형리스트
#  - 데이터로만 구성
#  - 물리적 순서와 논리적 순서가 동일
#  - 데이터 삽입, 삭제시 오버헤드 발생
#
# - 단순연결리스트
#  - 노드로 구성 = 데이터 + 링크(다음 데이터를 가리키는 주소)
#  - 데이터 삽입삭제시 링크만 변경하면되서 오버헤드 발생하지 않음.
#  - 한쪽방향으로만 진행가능. 첫노드는 head 노드로 부터 시작.

# %% [markdown]
# # 단순 연결리스트 간단

# %%
# 데이터가 5개인 단순연결 리스트 생성
class Node() :
	def __init__ (self) :
		self.data = None
		self.link = None

node1 = Node()
node1.data = "다현"

node2 = Node()
node2.data = "정연"
node1.link = node2

node3 = Node()
node3.data = "쯔위"
node2.link = node3

node4 = Node()
node4.data = "사나"
node3.link = node4

node5 = Node()
node5.data = "지효"
node4.link = node5
# Out:
# 다현 정연 쯔위 사나 지효 다현 정연 쯔위 사나 지효

# %%
# 리스트 출력
print(node1.data, end = ' ')
print(node1.link.data, end = ' ')
print(node1.link.link.data, end = ' ')
print(node1.link.link.link.data, end = ' ')
print(node1.link.link.link.link.data, end = ' ')
# Out:
# 다현 정연 쯔위 사나 지효

# %%
# 리스트 출력2
current = node1
print(current.data, end = ' ')
while current.link != None :
	 current = current.link
	 print(current.data, end = ' ')
# Out:
# 다현 정연 쯔위 사나 지효

# %%
# 노드 삽입
newNode = Node()
newNode.data = "재남"
newNode.link = node2.link   # 정연의 링크
node2.link = newNode

current = node1
print(current.data, end = ' ')
while current.link != None :	#끝노드를 만날때까지
	 current = current.link
	 print(current.data, end = ' ')
# Out:
# 다현 정연 재남 쯔위 사나 지효

# %%
# 노드 삭제 - 쯔위(node3)
node2.link = node3.link 	# 쯔위의 링크를 정연의 링크로 복사
del(node3) 		# 쯔위 삭제

current = node1
print(current.data, end = ' ')
while current.link != None :
	 current = current.link
	 print(current.data, end = ' ')
# Out:
# 다현 정연 사나 지효

# %% [markdown]
# # 단순 연결리스트 일반 구현

# %% [markdown]
# ### 단순연결리스트 생성

# %%
## 클래스와 함수 선언 부분 ## 
class Node() :
	def __init__ (self) :
		self.data = None
		self.link = None

def printNodes(start) :
	current = start         #current - 현재 노드 주소
	if current == None :
		return
	print(current.data, end = ' ')
	while current.link != None:
		current = current.link
		print(current.data, end = ' ')
	print()

## 전역 변수 선언 부분 ##
memory = []
head, current, pre = None, None, None
dataArray = ["다현", "정연", "쯔위", "사나", "지효"]

## 메인 코드 부분 ##
if __name__ == "__main__" :

	node = Node()		# 첫 번째 노드
	node.data = dataArray[0]
	head = node         # head - 첫 번째 노드 주소
	memory.append(node)

	for data in dataArray[1:] :	# 두 번째 이후 노드
		pre = node          	# pre - 이전 노드 주소
		node = Node()
		node.data = data
		pre.link = node	
		memory.append(node)

	printNodes(head)
# Out:
# 다현 정연 쯔위 사나 지효

# %% [markdown]
# ### 리스트 추가

# %%
## 클래스와 함수 선언 부분 ## 
class Node() :
	def __init__ (self) :
		self.data = None
		self.link = None

def printNodes(start) :
	current = start
	if current == None :
		return
	print(current.data, end = ' ')
	while current.link != None:
		current = current.link
		print(current.data, end = ' ')
	print()

def insertNode(findData, insertData) :
	global memory, head, current, pre

	if head.data == findData :      # 첫 번째 노드 삽입
		node = Node()
		node.data = insertData
		node.link = head
		head = node
		return

	current = head
	while current.link != None :    # 중간 노드 삽입
		pre = current
		current = current.link
		if current.data == findData :
			node = Node()
			node.data = insertData
			node.link = current
			pre.link = node
			return
	## 검색결과가 없으면 리턴
	print(findData, ' 노드가 없습니다.')
	return

	node = Node()                   # 마지막 노드 삽입
	node.data = insertData
	current.link = node
    

## 전역 변수 선언 부분 ##
memory = []
head, current, pre = None, None, None
dataArray = ["다현", "정연", "쯔위", "사나", "지효"]

## 메인 코드 부분 ##
if __name__ == "__main__" :

	node = Node()			# 첫 번째 노드
	node.data = dataArray[0]
	head = node
	memory.append(node)

	for data in dataArray[1:] :		# 두 번째 노드부터
		pre = node
		node = Node()
		node.data = data
		pre.link = node
		memory.append(node)

	printNodes(head)

	insertNode("다현", "화사") # 화사를 다현 앞에 추가
	printNodes(head)
# Out:
# 다현 정연 쯔위 사나 지효
# 화사 다현 정연 쯔위 사나 지효

# %%
insertNode("사나", "솔라")
printNodes(head)

insertNode("재남", "문별")
printNodes(head)
# Out:
# 화사 다현 정연 쯔위 솔라 사나 지효
# 재남  노드가 없습니다.
# 화사 다현 정연 쯔위 솔라 사나 지효

# %% [markdown]
# ### 리스트 삭제

# %%
## 클래스와 함수 선언 부분 ## 
class Node() :
	def __init__ (self) :
		self.data = None
		self.link = None

def printNodes(start) :
	current = start
	if current == None :
		return
	print(current.data, end = ' ')
	while current.link != None:
		current = current.link
		print(current.data, end = ' ')
	print()

def deleteNode(deleteData) :
	global memory, head, current, pre

	if head.data == deleteData :         # 첫 번째 노드 삭제
		current = head
		head = head.link
		del(current)
		return

	current = head                          # 첫 번째  외 노드 삭제
	while current.link != None :
		pre = current
		current = current.link
		if current.data == deleteData :
			pre.link = current.link
			del(current)
			return
	## 검색결과가 없으면 리턴
	print(deleteData, ' 노드가 없습니다.')
	return

## 전역 변수 선언 부분 ##
memory = []
head, current, pre = None, None, None
dataArray = ["다현", "정연", "쯔위", "사나", "지효"]

## 메인 코드 부분 ##
if __name__ == "__main__" :

	node = Node()			# 첫 번째 노드
	node.data = dataArray[0]
	head = node
	memory.append(node)

	for data in dataArray[1:] :		# 두 번째 노드부터
		pre = node
		node = Node()
		node.data = data
		pre.link = node
		memory.append(node)

	printNodes(head)

	deleteNode("다현")
	printNodes(head)

	deleteNode("쯔위")
	printNodes(head)

	deleteNode("지효")
	printNodes(head)

	deleteNode("재남")
	printNodes(head)
# Out:
# 다현 정연 쯔위 사나 지효
# 정연 쯔위 사나 지효
# 정연 사나 지효
# 정연 사나
# 재남  노드가 없습니다.
# 정연 사나

# %% [markdown]
# ### 리스트에서 검색

# %%
## 클래스와 함수 선언 부분 ## 
class Node() :
	def __init__ (self) :
		self.data = None
		self.link = None

def printNodes(start) :
	current = start
	if current == None :
		return
	print(current.data, end = ' ')
	while current.link != None:
		current = current.link
		print(current.data, end = ' ')
	print()

def findNode(findData) :
	global memory, head, current, pre

	current = head
	if current.data == findData :
		return current
	while current.link != None :
		current = current.link
		if current.data == findData :
			return current
	return Node()	# 빈 노드 반환

## 전역 변수 선언 부분 ##
memory = []
head, current, pre = None, None, None
dataArray = ["다현", "정연", "쯔위", "사나", "지효"]

## 메인 코드 부분 ##
if __name__ == "__main__" :

	node = Node()			# 첫 번째 노드
	node.data = dataArray[0]
	head = node
	memory.append(node)

	for data in dataArray[1:] :		# 두 번째 노드부터
		pre = node
		node = Node()
		node.data = data
		pre.link = node
		memory.append(node)

	printNodes(head)

	fNode = findNode("다현")
	print(fNode.data)

	fNode = findNode("쯔위")
	print(fNode.data)

	fNode = findNode("재남")
	print(fNode.data)
# Out:
# 다현 정연 쯔위 사나 지효
# 다현
# 쯔위
# None

# %% [markdown]
# ### 리스트에서 검색 및 수정

# %%
## 클래스와 함수 선언 부분 ## - 
class Node() :
	def __init__ (self) :
		self.data = None
		self.link = None

def printNodes(start) :
	current = start
	if current == None :
		return
	print(current.data, end = ' ')
	while current.link != None:
		current = current.link
		print(current.data, end = ' ')
	print()

def updateNode(findData, updateData) :
	global memory, head, current, pre

	current = head
	if current.data == findData :
		current.data = updateData
		return current
	while current.link != None :
		current = current.link
		if current.data == findData :
			current.data = updateData            
			return current
	return Node()	# 빈 노드 반환

## 전역 변수 선언 부분 ##
memory = []
head, current, pre = None, None, None
dataArray = ["다현", "정연", "쯔위", "사나", "지효"]

## 메인 코드 부분 ##
if __name__ == "__main__" :

	node = Node()			# 첫 번째 노드
	node.data = dataArray[0]
	head = node
	memory.append(node)

	for data in dataArray[1:] :		# 두 번째 노드부터
		pre = node
		node = Node()
		node.data = data
		pre.link = node
		memory.append(node)

	printNodes(head)

	updateNode("다현", '지수')
	printNodes(head)

	updateNode("쯔위", '제니')
	printNodes(head)

	updateNode("재남",'리사')
	printNodes(head)
# Out:
# 다현 정연 쯔위 사나 지효
# 지수 정연 쯔위 사나 지효
# 지수 정연 제니 사나 지효
# 지수 정연 제니 사나 지효

# %% [markdown]
# # 단순 연결리스트 응용
# - 명함관리 프로그램 - 이름 오름 차순 정렬

# %%
## 클래스와 함수 선언 부분 ##
class Node() :
	def __init__ (self) :
		self.data = None
		self.link = None

def printNodes(start) :
	current = start
	if current == None :
		return
	print(current.data, end = ' ')
	while current.link != None:
		current = current.link
		print(current.data, end = ' ')
	print()

def makeSimpleLinkedList(namePhone) :
	global memory, head, current, pre
	printNodes(head)

	node = Node()
	node.data = namePhone
	memory.append(node)
	if head == None :			# 첫 번째 노드일 때
		head = node
		return

	if head.data[0] > namePhone[0] :	# 첫 번째 노드보다 작을 때
		node.link = head
		head = node
		return

	# 중간 노드로 삽입하는 경우
	current = head
	while current.link != None :
		pre = current
		current = current.link
		
		if current.data[0] > namePhone[0]:
			pre.link = node
			node.link = current
			return

	# 삽입하는 노드가 가장 큰 경우
	current.link = node

## 전역 변수 선언 부분 ##
memory = []
head, current, pre = None, None, None
dataArray = [["지민", "010-1111-1111"], ["정국", "010-2222-2222"], ["뷔", "010-3333-3333"], ["슈가", "010-4444-4444"], ["진", "010-5555-5555"]]

## 메인 코드 부분 ##
if __name__ == "__main__" :

	for data in dataArray :
		makeSimpleLinkedList(data)

	printNodes(head)
# Out:
# ['지민', '010-1111-1111']
# ['정국', '010-2222-2222'] ['지민', '010-1111-1111']
# ['뷔', '010-3333-3333'] ['정국', '010-2222-2222'] ['지민', '010-1111-1111']
# 정국 슈가
# ['뷔', '010-3333-3333'] ['슈가', '010-4444-4444'] ['정국', '010-2222-2222'] ['지민', '010-1111-1111']
# 슈가 진
# 정국 진
# 지민 진
# ['뷔', '010-3333-3333'] ['슈가', '010-4444-4444'] ['정국', '010-2222-2222'] ['지민', '010-1111-1111'] ['진', '010-5555-5555']
